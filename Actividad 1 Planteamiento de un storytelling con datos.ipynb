# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiancanasg/diplomado/blob/main/Actividad%201%20Planteamiento%20de%20un%20storytelling%20con%20datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Actividad 1: Planteamiento de un storytelling con datos

# %% [markdown]
# # Importación de Bibliotecas
# ### Se importan las bibliotecas numpy y pandas para manipulación de arrays y trabajo con data frames, respectivamente.

# %%
import numpy as np # manipulación de arrays [0: escalar, 1: vector, 2: matriz, >2: tensor]
import pandas as pd #Trabajar con data frames

# %% [markdown]
# # Carga de Datos
# ### Se carga el conjunto de datos desde una URL en formato CSV usando pandas. El delimitador es especificado como ';' y se utiliza el encoding 'latin-1'.

# %%
# Get data

df = pd.read_csv('https://raw.githubusercontent.com/cristiancanasg/diplomado/main/VOZ_MOVIL_INGRESOS_20.csv', sep = ';',encoding= 'latin-1')

# %% [markdown]
# #Visualización de Datos:
# ###Estos comandos muestran las primeras filas, últimas filas y una muestra aleatoria de 5 filas del conjunto de datos, respectivamente.

# %%
# Previsualizar datos
df.head()
# Out:
#    ï»¿ANNO  TRIMESTRE  MES_DEL_TRIMESTRE  ID_EMPRESA  \
# 0     2011          1                  0   830016046
# 1     2011          1                  0   830114921
# 2     2011          1                  0   800153993
# 3     2011          1                  0   830037330
# 4     2011          2                  0   830016046
#
#                                EMPRESA INGRESOS_TOTALES INGRESOS_POSPAGO  \
# 0                        AVANTEL S.A.S      21352355073                0
# 1              COLOMBIA MOVIL  S.A ESP     161083356000      74415757000
# 2  COMUNICACION CELULAR S A COMCEL S A    1200162880000     682650702000
# 3     TELEFONICA MOVILES COLOMBIA S.A.     430783387000     347987789000
# 4                        AVANTEL S.A.S      21776191153                0
#
#   INGRESOS_PREPAGO CONSUMO_PREPAGO_ON CONSUMO_PREPAGO_OFF
# 0                0                  0                   0
# 1      86667599000                  0                   0
# ...

# %%
df.tail()
# Out:
#       ï»¿ANNO  TRIMESTRE  MES_DEL_TRIMESTRE  ID_EMPRESA  \
# 1305     2023          2                  3   900420122
# 1306     2023          2                  3   900973532
# 1307     2023          2                  3   901162121
# 1308     2023          2                  3   901354361
# 1309     2023          2                  3   901470579
#
#                              EMPRESA INGRESOS_TOTALES INGRESOS_POSPAGO  \
# 1305   VIRGIN MOBILE COLOMBIA S.A.S.       1431394696                0
# 1306               SUMA MOVIL S.A.S.         12324365                0
# 1307  LOGISTICA FLASH COLOMBIA S.A.S        266798288                0
# 1308   PARTNERS TELECOM COLOMBIA SAS       3193137520       3053257022
# 1309      LOV TELECOMUNICACIONES SAS         12369825                0
#
#      INGRESOS_PREPAGO CONSUMO_PREPAGO_ON CONSUMO_PREPAGO_OFF
# 1305       1431394696                  0                   0
# 1306         12324365                  0                   0
# ...

# %%
df.sample(5)
# Out:
#       ï»¿ANNO  TRIMESTRE  MES_DEL_TRIMESTRE  ID_EMPRESA  \
# 1239     2022          4                  3   900973532
# 76       2012          3                  3   830037330
# 125      2013          2                  1   830114921
# 111      2013          1                  2   800153993
# 621      2017          4                  2   900420122
#
#                                   EMPRESA INGRESOS_TOTALES INGRESOS_POSPAGO  \
# 1239                    SUMA MOVIL S.A.S.          8874918                0
# 76       TELEFONICA MOVILES COLOMBIA S.A.     159230427000     132404963000
# 125               COLOMBIA MOVIL  S.A ESP      59585187000      31248061000
# 111   COMUNICACION CELULAR S A COMCEL S A     416306261000     227998476000
# 621         VIRGIN MOBILE COLOMBIA S.A.S.       7867521825                0
#
#      INGRESOS_PREPAGO CONSUMO_PREPAGO_ON CONSUMO_PREPAGO_OFF
# 1239          8874918            2670800             6204118
# ...

# %% [markdown]
# # Información General de los Datos:
# ### shape devuelve la cantidad de filas y columnas del DataFrame, y columns devuelve los nombres de las columnas.

# %%
df.shape
# Out:
# (1310, 10)

# %%
df.columns
# Out:
# Index(['ï»¿ANNO', 'TRIMESTRE', 'MES_DEL_TRIMESTRE', 'ID_EMPRESA', 'EMPRESA',
#        'INGRESOS_TOTALES', 'INGRESOS_POSPAGO', 'INGRESOS_PREPAGO',
#        'CONSUMO_PREPAGO_ON', 'CONSUMO_PREPAGO_OFF'],
#       dtype='object')

# %%
name = ['ï»¿ANNO', 'TRIMESTRE', 'MES_DEL_TRIMESTRE', 'ID_EMPRESA', 'EMPRESA',
       'INGRESOS_TOTALES', 'INGRESOS_POSPAGO', 'INGRESOS_PREPAGO',
       'CONSUMO_PREPAGO_ON', 'CONSUMO_PREPAGO_OFF']
df.columns = name
df.columns
# Out:
# Index(['ï»¿ANNO', 'TRIMESTRE', 'MES_DEL_TRIMESTRE', 'ID_EMPRESA', 'EMPRESA',
#        'INGRESOS_TOTALES', 'INGRESOS_POSPAGO', 'INGRESOS_PREPAGO',
#        'CONSUMO_PREPAGO_ON', 'CONSUMO_PREPAGO_OFF'],
#       dtype='object')

# %%
df.sample()
# Out:
#      ï»¿ANNO  TRIMESTRE  MES_DEL_TRIMESTRE  ID_EMPRESA  \
# 205     2014          1                  1   830122566
#
#                                      EMPRESA INGRESOS_TOTALES  \
# 205  COLOMBIA TELECOMUNICACIONES S.A. E.S.P.     125164843190
#
#     INGRESOS_POSPAGO INGRESOS_PREPAGO CONSUMO_PREPAGO_ON CONSUMO_PREPAGO_OFF
# 205     107145214820      18019628370                  0                   0

# %% [markdown]
# # Muestra Aleatoria y Selección de Datos Específicos:
# ### Se muestra una fila aleatoria, una fila específica y el nombre de empresas en un rango específico.

# %%
# Pandas series == listas
# pandas data frame == diccionarios

df[299:300]
df[100:111]['EMPRESA']
# Out:
# 100                                       AVANTEL S.A.S
# 101                             COLOMBIA MOVIL  S.A ESP
# 102             COLOMBIA TELECOMUNICACIONES S.A. E.S.P.
# 103                 COMUNICACION CELULAR S A COMCEL S A
# 104    EMPRESA DE TELECOMUNICACIONES DE BOGOTA S.A. ESP
# 105                                       UFF MOVIL SAS
# 106                     UNE EPM TELECOMUNICACIONES S.A.
# 107                       VIRGIN MOBILE COLOMBIA S.A.S.
# 108                                       AVANTEL S.A.S
# 109                             COLOMBIA MOVIL  S.A ESP
# 110             COLOMBIA TELECOMUNICACIONES S.A. E.S.P.
# Name: EMPRESA, dtype: object

# %% [markdown]
# # Información Detallada del DataFrame:
# ### Este comando proporciona información detallada sobre el DataFrame, incluyendo el tipo de datos y la cantidad de valores no nulos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿ANNO              1310 non-null   int64
#  1   TRIMESTRE            1310 non-null   int64
#  2   MES_DEL_TRIMESTRE    1310 non-null   int64
#  3   ID_EMPRESA           1310 non-null   int64
#  4   EMPRESA              1310 non-null   object
#  5   INGRESOS_TOTALES     1310 non-null   object
#  6   INGRESOS_POSPAGO     1310 non-null   object
#  7   INGRESOS_PREPAGO     1310 non-null   object
#  8   CONSUMO_PREPAGO_ON   1089 non-null   object
#  9   CONSUMO_PREPAGO_OFF  1310 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 102.5+ KB
